# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Fast = np.genfromtxt('pubmed_Fast.csv',delimiter=',')
AS = np.genfromtxt('pubmed_AS.csv',delimiter=',')

# %%
plt.plot(AS[0,:],label = 'AS-GCN')
plt.plot(Fast[0,:],label = 'FastGCN')
#plt.plot(Vanilla_cora_train_acc,label = 'Vanilla-GCN')
plt.legend()
plt.title('Train Accuracy of 2 models over Pubmed Dataset')
plt.xlabel('Epoch [/] \n each number stand for 10 epochs (e.g. 0 stands for average of 0-9 epochs)')
plt.ylabel('Test Accuracy [/]')
# Out:
# Text(0, 0.5, 'Test Accuracy [/]')

# %%
plt.plot(AS[1,:],label = 'AS-GCN')
plt.plot(Fast[1,:],label = 'FASTGCN')
#plt.plot(Vanilla_cora_test_acc,label = 'Vanilla-GCN')
plt.legend()
plt.title('Test Accuracy of 2 models over Pubmed Dataset')
plt.xlabel('Epoch [/] \n each number stand for 10 epochs (e.g. 0 stands for average of 0-9 epochs)')
plt.ylabel('Test Accuracy [/]')
# Out:
# Text(0, 0.5, 'Test Accuracy [/]')

# %%
plt.plot(AS[2,:],label = 'AS-GCN')
plt.plot(Fast[2,:],label = 'FASTGCN')
#plt.plot(Vanilla_cora_train_times,label = 'Vanilla-GCN')
plt.legend()
plt.title('Train Times of 2 models over Pubmed Dataset')
plt.xlabel('Epoch [/] \n each number stand for 10 epochs (e.g. 0 stands for average of 0-9 epochs)')
plt.ylabel('Train Times [s]')
# Out:
# Text(0, 0.5, 'Train Times [s]')

# %%
Fast_Cora = np.genfromtxt('FastGCN_Cora.csv',delimiter=',')
Fast_Alt_Cora = np.genfromtxt('Fast_Alt_Cora.csv',delimiter=',')
Hybrid_Cora = np.genfromtxt('Hybrid_Cora.csv',delimiter=',')
Fast_Alt2_Cora = np.genfromtxt('Fast_Alt2_Cora.csv',delimiter=',')

Fast_Pubmed = np.genfromtxt('FastGCN_Pubmed.csv',delimiter=',')
Fast_Alt_Pubmed = np.genfromtxt('Fast_Alt_Pubmed.csv',delimiter=',')
Hybrid_Pubmed = np.genfromtxt('Hybrid_Pubmed.csv',delimiter=',')
Fast_Alt2_Pubmed = np.genfromtxt('Fast_Alt2_Pubmed.csv',delimiter=',')

# %%
plt.plot(Fast_Cora[0,:],label = 'FastGCN')
plt.plot(Fast_Alt_Cora[0,:],label = 'FastGCN_Alt1')
plt.plot(Hybrid_Cora[0,:],label = 'Hybrid')
plt.plot(Fast_Alt2_Cora[0,:],label = 'FastGCN_Alt2')
plt.legend()
plt.title('Train Accuracy of 4 models over Cora Dataset')
plt.xlabel('Epoch [/] \n each number stand for 10 epochs (e.g. 0 stands for average of 0-9 epochs)')
plt.ylabel('Train Accuracy [/]')
# Out:
# Text(0, 0.5, 'Train Accuracy [/]')

# %%
plt.plot(Fast_Cora[1,:],label = 'FastGCN')
plt.plot(Fast_Alt_Cora[1,:],label = 'FastGCN_Alt1')
plt.plot(Hybrid_Cora[1,:],label = 'Hybrid')
plt.plot(Fast_Alt2_Cora[1,:],label = 'FastGCN_Alt2')
plt.legend()
plt.title('Test Accuracy of 4 models over Cora Dataset')
plt.xlabel('Epoch [/] \n each number stand for 10 epochs (e.g. 0 stands for average of 0-9 epochs)')
plt.ylabel('Test Accuracy [/]')
# Out:
# Text(0, 0.5, 'Test Accuracy [/]')

# %%
plt.plot(Fast_Cora[2,:],label = 'FastGCN')
plt.plot(Fast_Alt_Cora[2,:],label = 'FastGCN_Alt1')
plt.plot(Hybrid_Cora[2,:],label = 'Hybrid')
plt.plot(Fast_Alt2_Cora[2,:],label = 'FastGCN_Alt2')
plt.legend()
plt.title('Train Time of 4 models over Cora Dataset')
plt.xlabel('Epoch [/] \n each number stand for 10 epochs (e.g. 0 stands for average of 0-9 epochs)')
plt.ylabel('Train Time [/]')
# Out:
# Text(0, 0.5, 'Train Time [/]')

# %%
plt.plot(Fast_Pubmed[0,:],label = 'FastGCN')
plt.plot(Fast_Alt_Pubmed[0,:],label = 'FastGCN_Alt1')
plt.plot(Hybrid_Pubmed[0,:],label = 'Hybrid')
plt.plot(Fast_Alt2_Pubmed[0,:],label = 'FastGCN_Alt2')
plt.legend()
plt.title('Train Accuracy of 4 models over Pubmed Dataset')
plt.xlabel('Epoch [/] \n each number stand for 10 epochs (e.g. 0 stands for average of 0-9 epochs)')
plt.ylabel('Train Accuracy [/]')
# Out:
# Text(0, 0.5, 'Train Accuracy [/]')

# %%
plt.plot(Fast_Pubmed[1,:],label = 'FastGCN')
plt.plot(Fast_Alt_Pubmed[1,:],label = 'FastGCN_Alt1')
plt.plot(Hybrid_Pubmed[1,:],label = 'Hybrid')
plt.plot(Fast_Alt2_Pubmed[1,:],label = 'FastGCN_Alt2')
plt.legend()
plt.title('Test Accuracy of 4 models over Pubmed Dataset')
plt.xlabel('Epoch [/] \n each number stand for 10 epochs (e.g. 0 stands for average of 0-9 epochs)')
plt.ylabel('Test Accuracy [/]')
# Out:
# Text(0, 0.5, 'Test Accuracy [/]')

# %%
plt.plot(Fast_Pubmed[2,:],label = 'FastGCN')
plt.plot(Fast_Alt_Pubmed[2,:],label = 'FastGCN_Alt1')
plt.plot(Hybrid_Pubmed[2,:],label = 'Hybrid')
plt.plot(Fast_Alt2_Pubmed[2,:],label = 'FastGCN_Alt2')
plt.legend()
plt.title('Train Time of 4 models over Pubmed Dataset')
plt.xlabel('Epoch [/] \n each number stand for 10 epochs (e.g. 0 stands for average of 0-9 epochs)')
plt.ylabel('Train Time [/]')
# Out:
# Text(0, 0.5, 'Train Time [/]')

# %%
##Documented Manually##
##FastAlt -> Uniform##
PUBMED = [0.834,0.832,0.850,0.826,0.825,0.840,0.846,0.817,0.819,0.816,0.822]
CORA = [0.846,0.845,0.860,0.837,0.853,0.856,0.853,0.849,0.844,0.849,0.845]
c = np.linspace(0,1,11)

# %%
plt.plot(c,PUBMED,label = 'Pubmed Dataset')
plt.plot(c,CORA, label = 'Cora Dataset')
plt.plot([0.2,0.2],[0.80,0.88])
plt.xlabel('The value of c (0.1 interval from 0-1)')
plt.ylabel('Test Accuracy')
plt.title('Test Accuracy for different value of c on two datasets')
plt.legend()
